LFU =  [0.38100000000000006, 0.40540000000000126, 0.39559999999999995, 0.4112000000000049, 0.3802000000000012, 0.3977999999999997, 0.3919999999999999, 0.41000000000000014, 0.40700000000000314, 0.39559999999999995, 0.3628, 0.38459999999999983, 0.3904000000000005, 0.3543999999999947, 0.3690000000000051, 0.36319999999997243, 0.38580000000000325, 0.3873999999999995, 0.3935999999999993]
# LRU = 
NOC = [0.3183999999999999, 0.40339999999999887, 0.38319999999999943, 0.3794000000000042, 0.36819999999999076, 0.35640000000000027, 0.40199999999999747, 0.4165999999999994, 0.4059999999999979, 0.3998000000000004, 0.37319999999999975, 0.4009999999999998, 0.38759999999999994, 0.40260000000000495, 0.36660000000001247, 0.3907999999999845, 0.39860000000005247, 0.40059999999999985]
x= ['5_4', '5_11', '5_13', '5_16', '5_18', '5_20', '5_21', '5_22', '6_0', '6_3', '6_10', '6_13', '6_15', '6_17', '6_19', '6_21', '6_22', '6_23']
x = [4,11,13,16,18,20,21,22,24,27,34,37,39,41,43,45,46,47]
x = ['4','11','13','16','18','20','21','22','24','27','34','37','39','41','43','45','46','47']
# x = [str(i) for i in x]
fig, ax = plt.subplots()
# plt.plot(x,ngram,label='ngram='+str(round(sum(ngram)/len(ngram),4)))
# plt.plot(x,ngram_d,label='ngram_d='+str(round(sum(ngram_d)/len(ngram_d),4)))
# plt.plot(x,PEC,label='PEC='+str(round(sum(PEC)/len(PEC),4)))
plt.plot(x,PEC,label='PEC='+str(round(sum(PEC)/len(PEC),4)))
plt.plot(x,CEC[0:18],label='CEC='+str(round(sum(CEC)/len(CEC),4)))
plt.plot(x,NOC[0:18],label='NOC='+str(round(sum(NOC)/len(NOC),4)))
plt.plot(x,LRU2,label='LRU2='+str(round(sum(LRU2)/len(LRU2),4)))
plt.plot(x,LFU[0:18],label='LFU='+str(round(sum(LFU)/len(LFU),4)))

plt.title('cache size = 2000')
plt.xlabel('time/h')
plt.ylabel('Hit Ratio')
# plt.legend()
plt.legend(fancybox=True,framealpha=0.01,prop={'size':9})
plt.savefig('eps_figures/twodayCS2k_highq.png',dpi=1200)
# fig.autofmt_xdate()
plt.show()

# %%
#two days test ratio=0.9, topk10
# ngram = [0.4056, 0.4428, 0.4138, 0.4232, 0.4136, 0.3604, 0.3858, 0.3552, 0.3774, 0.4454, 0.4194, 0.4048, 0.4012, 0.4148, 0.3744, 0.3778, 0.3968, 0.376]
          
# ngram_d = [0.4372, 0.5294, 0.4268, 0.4242, 0.4134, 0.36, 0.386, 0.3552, 0.3776, 0.4744, 0.5044, 0.4218, 0.3998, 0.4148, 0.3744, 0.3778, 0.3966, 0.376]
# ngram_d = [0.4662, 0.554, 0.4696, 0.4686, 0.4466, 0.4084, 0.4206, 0.3816, 0.4132, 0.516, 0.537, 0.4806, 0.4448, 0.4592, 0.439, 0.438, 0.4304, 0.41]
LFU =  [0.38100000000000006, 0.40540000000000126, 0.39559999999999995, 0.4112000000000049, 0.3802000000000012, 0.3977999999999997, 0.3919999999999999, 0.41000000000000014, 0.40700000000000314, 0.39559999999999995, 0.3628, 0.38459999999999983, 0.3904000000000005, 0.3543999999999947, 0.3690000000000051, 0.36319999999997243, 0.38580000000000325, 0.3873999999999995, 0.3935999999999993]
NOC = [0.3183999999999999, 0.40339999999999887, 0.38319999999999943, 0.3794000000000042, 0.36819999999999076, 0.35640000000000027, 0.40199999999999747, 0.4165999999999994, 0.4059999999999979, 0.3998000000000004, 0.37319999999999975, 0.4009999999999998, 0.38759999999999994, 0.40260000000000495, 0.36660000000001247, 0.3907999999999845, 0.39860000000005247, 0.40059999999999985]
x= ['5_4', '5_11', '5_13', '5_16', '5_18', '5_20', '5_21', '5_22', '6_0', '6_3', '6_10', '6_13', '6_15', '6_17', '6_19', '6_21', '6_22', '6_23']
x = [4,11,13,16,18,20,21,22,24,27,34,37,39,41,43,45,46,47]
x = ['4','11','13','16','18','20','21','22','24','27','34','37','39','41','43','45','46','47']
# x = [str(i) for i in x]
fig, ax = plt.subplots()
# plt.plot(x,ngram,label='ngram='+str(round(sum(ngram)/len(ngram),4)))
plt.plot(x,PEC_d,label='PEC='+str(round(sum(PEC_d)/len(PEC_d),4)))
plt.plot(x,ngram_d,label='Naive-PEC='+str(round(sum(ngram_d)/len(ngram_d),4)))
# plt.plot(x,PEC,label='PEC='+str(round(sum(PEC)/len(PEC),4)))

# plt.plot(x,PEC0_25,label='PEC0_25='+str(round(sum(PEC0_25)/len(PEC0_25),4)))
# plt.plot(x,PEC1,label='PEC1='+str(round(sum(PEC1)/len(PEC1),4)))
# plt.plot(x,PEC_ratio0_5,label='PEC_ratio0_5='+str(round(sum(PEC_ratio0_5)/len(PEC_ratio0_5),4)))
# plt.plot(x,LRU2,label='LRU2='+str(round(sum(LRU2)/len(LRU2),4)))
plt.plot(x,CEC[0:18],label='CEC='+str(round(sum(CEC)/len(CEC),4)))
# plt.plot(x,LFU_5k[0:18],label='LFU_5k='+str(round(sum(LFU_5k)/len(LFU_5k),4)))
# plt.plot(x,LFU[0:18],label='LFU='+str(round(sum(LFU)/len(LFU),4)))
# plt.plot(x,NOC[0:18],label='NOC='+str(round(sum(NOC)/len(NOC),4)))
plt.title('cache size = 2000')
plt.xlabel('time/h')
plt.ylabel('Hit Ratio')
plt.legend(fancybox=True,framealpha=0.01,prop={'size':9})
plt.savefig('eps_figures/prediction_simple_selfattention_highq.png',dpi=1200)
plt.show()

# %%
x = ['4','11','13','16','18','20','21','22','24','27','34','37','39','41','43','45','46','47']
# PEC = [4215, 4450, 4000, 3957, 3892, 3419, 3120, 2607, 3026, 4038, 4488, 3896, 3912, 3913, 3669, 3194, 2943, 2878]
# req_rate = [19.863603257630935, 11.781338360037699, 32.552083333333336, 34.762456546929315, 37.00962250185048, 47.206923682140044, 59.97600959616153, 74.36787307882994, 61.80469715698393, 26.25131256562828, 11.059500110595001, 35.714285714285715, 36.97769012695674, 38.16308357715303, 42.31311706629055, 57.449253159708924, 68.82312456985547, 66.25441696113074]

PEC = [16.728860658991664, 10.543725936984364, 25.629677839245037, 27.275886031966643, 28.82607085544994, 32.13408876298395, 37.52849430113977, 39.2313414331763, 37.23583934088568, 21.315030165253127, 9.980824544582935, 27.74393146120895, 28.33312800295676, 29.877769289533994, 31.265340668641556, 37.41379310344828, 40.788990825688074, 38.203487088942836]
req_rate = [19.84914648670107, 11.785966842146617, 32.54149040026034, 34.746351633078525, 37.032465127762, 47.214353163361665, 59.9880023995201, 74.38631291842302, 61.79196704428425, 26.23065489201714, 11.06276274061509, 35.69728700618753, 36.95946778366392, 38.19709702062643, 42.319085907744395, 57.47126436781609, 68.80733944954129, 66.21054954756124]
plt.plot(x, PEC, color="C0",label='prefetching count')
plt.plot(x, req_rate, color="C1",label='user request')
plt.xlabel('time/h')
plt.ylabel('number/minute')
plt.title('cache size = 2000')
# plt.legend()
plt.legend(fancybox=True,framealpha=0.01,prop={'size':9})
plt.savefig('eps_figures/prefetchtimesrequesttimes2ktwodaynew_highq.png',dpi=1200)
plt.show()

# %%
# cache size = 2000
ratio0_1 = [0.4022, 0.5376, 0.466, 0.45, 0.4152, 0.3942, 0.4146, 0.4012]
ratio0_3 = [0.4672, 0.588, 0.4982, 0.4898, 0.4554, 0.434, 0.455, 0.4438]
ratio0_5 = [0.502, 0.608, 0.5066, 0.4994, 0.465, 0.4432, 0.467, 0.4606]
ratio0_6 = [0.5158, 0.5998, 0.5242, 0.515, 0.476, 0.4478, 0.466, 0.467]
ratio0_7 = [0.5146, 0.5922, 0.533, 0.5288, 0.4902, 0.4542, 0.4658, 0.46]
ratio0_8 = [0.509, 0.5826, 0.5344, 0.537, 0.5042, 0.4566, 0.4688, 0.4538]
ratio0_9 = [0.494, 0.566, 0.5268, 0.5318, 0.5068, 0.4552, 0.4626, 0.4442]
ratio1_0 = [0.4386, 0.4508, 0.4528, 0.4752, 0.4702, 0.3988, 0.4056, 0.4058]
adjust = [0.5078, 0.6112, 0.5336, 0.5416, 0.5078, 0.4584, 0.4628, 0.4432]
# adjust = [0.504, 0.6074, 0.5244, 0.526, 0.49, 0.4594, 0.4674, 0.4434]

x = ['4','11','13','16','18','20','21','22']
# plt.plot(x,ratio0_1,label='ratio0_1='+str(round(sum(ratio0_1)/len(ratio0_1),4)))
plt.plot(x,ratio0_3,label='ratio0.3='+str(round(sum(ratio0_3)/len(ratio0_3),4)))
plt.plot(x,ratio0_5,label='ratio0.5='+str(round(sum(ratio0_5)/len(ratio0_5),4)))
plt.plot(x,ratio0_6,label='ratio0.6='+str(round(sum(ratio0_6)/len(ratio0_6),4)))
plt.plot(x,ratio0_7,label='ratio0.7='+str(round(sum(ratio0_7)/len(ratio0_7),4)))
plt.plot(x,ratio0_8,label='ratio0.8='+str(round(sum(ratio0_8)/len(ratio0_8),4)))
plt.plot(x,ratio0_9,label='ratio0.9='+str(round(sum(ratio0_9)/len(ratio0_9),4)))
plt.plot(x,adjust,label='dynamic ratio='+str(round(sum(adjust)/len(adjust),4)),marker='o')
plt.title('HR, cache size = 2000, different partition ratio')
plt.xlabel('time/h')
plt.ylabel('Hit Ratio')
plt.legend(fancybox=True,framealpha=0.01,prop={'size':9})
plt.savefig('eps_figures/dynamic_ratio_highq.png',dpi=1200)
plt.show()

# %%
total_width,n = 0.8,7
width = total_width/n
plt.rcParams['figure.figsize']=(16.0, 3.0)
texture=['//','.','\\']
#A1
PEC = [0.2685,0.3624,0.4869,0.6593]
LRU2 = [0.2158,0.2851,0.3689,0.4941]
LRU = [0.1918,0.2596,0.3469,0.4770]
LFU = [0.2332,0.2967,0.3713, 0.4824]
LRB = [0.2021, 0.2690, 0.3549, 0.4828]
CEC = [0.2575, 0.3326, 0.4243, 0.5535]
NOC = [0.2460, 0.3079, 0.3864, 0.4822]
name_list = ['500','1000','2000','5000']
x = list(range(len(name_list)))

fig, axs = plt.subplots(1,4)
axs[0].bar(x, PEC, width = width, label='PEC')

for i in range(len(x)):
    x[i] = x[i] + width
axs[0].bar(x,LRU2, width = width,label='LRU2')

for i in range(len(x)):
    x[i] = x[i] + width
axs[0].bar(x,LRU, width = width,label='LRU', tick_label = name_list)

for i in range(len(x)):
    x[i] = x[i] + width
axs[0].bar(x,LFU, width = width,label='LFU')

for i in range(len(x)):
    x[i] = x[i] + width
axs[0].bar(x,LRB, width = width,label='LRB')

for i in range(len(x)):
    x[i] = x[i] + width
axs[0].bar(x,CEC, width = width,label='CEC')

for i in range(len(x)):
    x[i] = x[i] + width
axs[0].bar(x,NOC, width = width,label='NOC')
axs[0].set_title('dataset $A_1$(first-day testing data)')
axs[0].set_xlabel('(a)')


#A2
PEC = [0.1652, 0.2213, 0.2948, 0.4100, 0.5079]
LRU2 = [0.1059, 0.1326, 0.1658, 0.2398, 0.3150]
LRU = [0.1203, 0.1481, 0.1891, 0.2575, 0.3144]
LFU = [0.0884, 0.1176, 0.1567, 0.2311, 0.2968]
LRB = [0.1294, 0.1590, 0.1995, 0.2671, 0.3230]
CEC = [0.1285, 0.1558, 0.2027, 0.2818, 0.3667]
NOC = [0.1143, 0.1372, 0.1734, 0.2327, 0.2905]
name_list = ['50','100','200','500','1000']
x = list(range(len(name_list)))

axs[1].bar(x, PEC, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[1].bar(x,LRU2, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[1].bar(x,LRU, width = width, tick_label = name_list)

for i in range(len(x)):
    x[i] = x[i] + width
axs[1].bar(x,LFU, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[1].bar(x,LRB, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[1].bar(x,CEC, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[1].bar(x,NOC, width = width)
axs[1].set_title('dataset $A_2$')
axs[1].set_xlabel('(b)')

#B1
PEC = [0.2346, 0.4492, 0.5369, 0.6184]
LRU2 = [0.2575, 0.4047, 0.4728, 0.5396]
LRU = [0.1986, 0.3839, 0.4649, 0.5391]
LFU = [0.2504, 0.4055, 0.4655, 0.5244]
LRB = [0.1976, 0.3810, 0.4604, 0.5244]
CEC = [0.2986, 0.4576, 0.5159, 0.5947]
NOC = [0.2944, 0.4351, 0.4833, 0.5354]
name_list = ['100','500','1000','2000']
x = list(range(len(name_list)))

axs[2].bar(x, PEC, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[2].bar(x,LRU2, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[2].bar(x,LRU, width = width, tick_label = name_list)

for i in range(len(x)):
    x[i] = x[i] + width
axs[2].bar(x,LFU, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[2].bar(x,LRB, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[2].bar(x,CEC, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[2].bar(x,NOC, width = width)
axs[2].set_title('dataset $B_1$')
axs[2].set_xlabel('(c)')


#B2
PEC = [0.1893, 0.2760, 0.3589, 0.4845, 0.5681]
LRU2 = [0.2076, 0.2672, 0.3289, 0.4200, 0.4880]
LRU = [0.1548, 0.2240, 0.3025, 0.4079, 0.4890]
LFU = [0.2053, 0.2572, 0.3202, 0.4086, 0.4695]
LRB = [0.1547, 0.2242, 0.3024, 0.4080, 0.4891]
CEC = [0.2464, 0.3073, 0.3717, 0.4639, 0.5463]
NOC = [0.2511, 0.3009, 0.3546, 0.4299, 0.4813]
name_list = ['50','100','200','500','1000']
x = list(range(len(name_list)))

axs[3].bar(x, PEC, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[3].bar(x,LRU2, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[3].bar(x,LRU, width = width, tick_label = name_list)

for i in range(len(x)):
    x[i] = x[i] + width
axs[3].bar(x,LFU, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[3].bar(x,LRB, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[3].bar(x,CEC, width = width)

for i in range(len(x)):
    x[i] = x[i] + width
axs[3].bar(x,NOC, width = width)
axs[3].set_title('dataset $B_2$')
axs[3].set_xlabel('(d)')

fig.legend(ncol=7,bbox_to_anchor=(0.76,1.15),prop={'size':12})
plt.savefig('eps_figures/hit-ratio-on-4-different-datasets_horizental.png',dpi=1200)
#fig.autofmt_xdate()
#fig.show()
